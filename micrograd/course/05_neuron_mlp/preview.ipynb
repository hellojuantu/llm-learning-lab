# %% [markdown]
# # Preview - Neuron(n) 的 n
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

import importlib
import course.checks as course_checks
importlib.reload(course_checks)
qa_check = course_checks.qa_check

# %%
# 填写说明：
# - 填三个数字：Neuron(3) 的输入数、输出数、参数数。
# - 填完后运行本 cell，看 qa_check 的提示。

# TODO: Neuron(3) 接收几个输入？有几个输出？有几个参数？
student_inputs = None
student_outputs = None
student_params = None


qa_check('qa_check_preview_05', globals(), student_inputs, student_outputs, student_params)

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 把形状说成人话：`Neuron(n)` 接收 n 个输入、输出 1 个数、参数是 n 个权重加 1 个 bias。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `inputs` 填 `3`。
# - `outputs` 填 `1`。
# - `params` 填 `4`。
#
# </details>
