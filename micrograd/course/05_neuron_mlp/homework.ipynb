# %% [markdown]
# # Homework 05 - Neuron / Layer / MLP
#
# 目标：把数学形状、Python list、神经元参数数量对应起来。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

from course.checks import qa_check

# %% [markdown]
# ## 完整例子 - 一个神经元就是点积加 bias
#
# `Neuron(2)` 接收两个输入，内部有两个权重和一个 bias，输出一个数。

# %%
w = [0.2, -0.5]
x = [2.0, -3.0]
b = 0.1
act = sum((wi*xi for wi, xi in zip(w, x)), b)
print('w0*x0 + w1*x1 + b =', act)

# %% [markdown]
# ## Modify - 从 Neuron(2) 改到 Neuron(3)
#
# 只多一个输入，就多一个权重，但输出仍然是一个数。

# %%
# 填写说明：
# - 填三个数字：Neuron(3) 的 weight 数、bias 数、输出数。
# - 填完后运行本 cell，看 qa_check 的提示。

student_neuron3_weight_count = None
student_neuron3_bias_count = None
student_neuron3_output_count = None



qa_check('qa_check_05_modify', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 把形状说成人话：`Neuron(n)` 接收 n 个输入、输出 1 个数、参数是 n 个权重加 1 个 bias。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `student_neuron3_weight_count` 填 `3`。
# - `student_neuron3_bias_count` 填 `1`。
# - `student_neuron3_output_count` 填 `1`。
#
# </details>

# %%
# 填写说明：
# - 按注释填点积数字、形状列表、层形状列表和参数总数。
# - 填完后运行本 cell，看 qa_check 的提示。

from micrograd.nn import Neuron, Layer, MLP

# 作业 1：点积 [2,-1,3] dot [4,5,-2]
student_dot = None

# 作业 2：Neuron(3) 的输入数、输出数、参数数
student_neuron3_shape = None  # [inputs, outputs, params]

# 作业 3：Layer(2,3) 展开成几个 Neuron，里面每个 Neuron 接收几个输入？
student_layer23 = None # [neuron_count, each_neuron_input_count]

# 作业 4：MLP(2,[3,1]) 两层形状
student_mlp_layers = None # [(2,3), (3,1)]

# 作业 5：MLP(2,[3,1]) 参数数量
student_mlp_param_count = None



qa_check('qa_check_neuron_mlp', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 把形状说成人话：`Neuron(n)` 接收 n 个输入、输出 1 个数、参数是 n 个权重加 1 个 bias。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `student_dot` 填 `2*4 + (-1)*5 + 3*(-2)`。
# - `student_neuron3_shape` 填 `[3, 1, 4]`。
# - `student_layer23` 填 `[3, 2]`。
# - `student_mlp_layers` 填 `[(2, 3), (3, 1)]`。
# - `student_mlp_param_count` 填 `13`。
#
# </details>

# %%
# 填写说明：
# - 完成 student_layer_bias_probe，用 Layer(2,3) 的真实结构数 bias。
# - 返回顺序固定：neuron_count、bias_count、total_params。
# - 运行本 cell，看 qa_check 的提示。

from micrograd.nn import Layer


def student_layer_bias_probe():
    layer = Layer(2, 3)
    # TODO: return neuron_count, bias_count, total_params
    pass


qa_check('qa_check_bias_debug', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - `Layer(2,3)` 里面是 3 个 `Neuron(2)`。
# - 每个神经元都有自己的 2 个权重和 1 个 bias。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
# ```python
# def student_layer_bias_probe():
#     layer = Layer(2, 3)
#     neuron_count = len(layer.neurons)
#     bias_count = len(layer.neurons)
#     total_params = len(layer.parameters())
#     return neuron_count, bias_count, total_params
# ```
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 提示</summary>
#
# 先找完整例子的形状，再只改一个地方。填 TODO 前，先用小数字在纸上算一遍；测试失败时先判断错在数学、Python、计算图还是训练循环。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 答案</summary>
#
# 答案不要一开始看。正确答案应该能由完整例子和 Modify 题一步推出；如果你需要直接看答案，说明前一个台阶还没踩稳。
#
# </details>

# %% [markdown]
# ## 提交清单
#
# - [ ] 我跑过完整例子。
# - [ ] 我完成了 Modify 题。
# - [ ] 我完成了 TODO 作业并通过 qa_check。
# - [ ] 我修过 Debug Lab。
# - [ ] 我能说出本节知识如何接回 micrograd 主线。
