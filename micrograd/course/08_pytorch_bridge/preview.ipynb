# %% [markdown]
# # Preview - micrograd 到 PyTorch
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

from course.checks import qa_check

# %%
# 填写说明：
# - 填字符串：从注释给的两个 PyTorch 写法里选一个，表示可求导 Tensor。
# - 填完后运行本 cell，看 qa_check 的提示。

# TODO: micrograd 的 Value(2.0) 在 PyTorch 里最像哪种写法？填字符串。
# 可选：'torch.tensor(2.0)' / 'torch.tensor(2.0, requires_grad=True)'
student_answer = None


qa_check('qa_check_preview_08', globals(), student_answer)

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 把 micrograd 词汇翻译过去：`Value -> Tensor(requires_grad=True)`，`backward -> loss.backward()`，更新由 optimizer 接手。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `answer` 填 `'torch.tensor(2.0, requires_grad=True)'`。
#
# </details>
