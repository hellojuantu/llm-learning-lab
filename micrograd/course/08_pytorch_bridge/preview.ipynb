# %% [markdown]
# # Preview - micrograd 到 PyTorch
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

import importlib
import course.checks as course_checks
importlib.reload(course_checks)
qa_check = course_checks.qa_check

# %%
# 填写说明：
# - 创建一个真正的 PyTorch Tensor，不要写概念名字。
# - 运行本 cell，看 qa_check 的提示。

try:
    import torch
except Exception as exc:
    torch = None
    print('torch 未安装。先运行: .venv/bin/python -m pip install -r course/requirements-course.txt')

# TODO: 如果 torch 可用，创建值为 2.0、requires_grad=True 的标量 Tensor。
student_tensor = None


qa_check('qa_check_preview_08', globals(), student_tensor)

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 这里要创建对象，不是写一段文字。
# - PyTorch 只有 `requires_grad=True` 的 Tensor 才会记录梯度。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
# ```python
# student_tensor = torch.tensor(2.0, requires_grad=True)
# ```
#
# </details>
