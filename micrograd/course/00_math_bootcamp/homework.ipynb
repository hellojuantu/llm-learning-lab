# %% [markdown]
# # Homework 00 - Math Bootcamp
#
# 目标：把导数、偏导、梯度、链式法则变成能手算的小工具。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

import importlib
import course.checks as course_checks
importlib.reload(course_checks)
qa_check = course_checks.qa_check

# %% [markdown]
# ## 完整例子 - 先用代码看斜率
#
# 先不要背导数。我们用两个很近的点算 `(y2-y1)/(x2-x1)`。

# %%
def f_example(x):
    return 2*x + 1

x0 = 3.0
h = 0.0001
slope_example = (f_example(x0 + h) - f_example(x0)) / h
print('y=2x+1 在 x=3 附近的斜率约等于:', round(slope_example, 4))

# %% [markdown]
# ## Modify - 只改一行
#
# 参考上面的例子，把函数改成 `y=-3x+4`，观察斜率。

# %%
# 填写说明：
# - 先改 f_modify 的 return，让它表示指定直线；再填一个数字表示斜率。
# - 填完后运行本 cell，看 qa_check 的提示。

def f_modify(x):
    # TODO: 只改这一行，让它表示 y = -3*x + 4
    return None

student_modify_slope = None



qa_check('qa_check_00_modify', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 先用小数字画路径：一元题看斜率，多元题固定另一个变量，链式题把路径贡献相乘。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `measured` 约等于 `-3`。
# - `student_modify_slope` 填 `-3`。
#
# </details>

# %%
# 填写说明：
# - 填 5 个数字：两个斜率、两个偏导、一个链式法则结果。
# - 填完后运行本 cell，看 qa_check 的提示。

# 作业 1：一元导数就是局部斜率
# y = 2x + 1
student_slope_1 = None

# 作业 2：参考作业 1，换成 y = -3x + 4
student_slope_2 = None

# 作业 3：L = a*b + a，在 a=2,b=3 处，固定 b 求 dL/da
student_dL_da = None

# 作业 4：参考作业 3，固定 a 求 dL/db
student_dL_db = None

# 作业 5：y=(3x+1)^2，在 x=2 处 dy/dx
student_chain = None


qa_check('qa_check_math_bootcamp', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 先用小数字画路径：一元题看斜率，多元题固定另一个变量，链式题把路径贡献相乘。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `student_slope_1` 填 `2`。
# - `student_slope_2` 填 `-3`。
# - `student_dL_da` 填 `4`。
# - `student_dL_db` 填 `2`。
# - `student_chain` 填 `42`。
#
# </details>

# %% [markdown]
# ## Debug Lab
#
# 下面不是填公式，而是修正错误理解。

# %%
# 填写说明：
# - 填两个数字：ReLU(3) 的值，以及 L=a+a 时 dL/da。
# - 填完后运行本 cell，看 qa_check 的提示。

# Debug 1：有人说 ReLU(x) 在 x>0 时值等于 1。请填正确的 ReLU(3)。
student_relu_value_at_3 = None

# Debug 2：L = a + a 时，有两条路径都回到 a。dL/da 是多少？
student_repeated_path_grad = None



qa_check('qa_check_math_debug', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 先用小数字画路径：一元题看斜率，多元题固定另一个变量，链式题把路径贡献相乘。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `student_relu_value_at_3` 填 `3`。
# - `student_repeated_path_grad` 填 `2`。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 提示</summary>
#
# 先找完整例子的形状，再只改一个地方。填 TODO 前，先用小数字在纸上算一遍；测试失败时先判断错在数学、Python、计算图还是训练循环。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 答案</summary>
#
# 答案不要一开始看。正确答案应该能由完整例子和 Modify 题一步推出；如果你需要直接看答案，说明前一个台阶还没踩稳。
#
# </details>

# %% [markdown]
# ## 提交清单
#
# - [ ] 我跑过完整例子。
# - [ ] 我完成了 Modify 题。
# - [ ] 我完成了 TODO 作业并通过 qa_check。
# - [ ] 我修过 Debug Lab。
# - [ ] 我能说出本节知识如何接回 micrograd 主线。
