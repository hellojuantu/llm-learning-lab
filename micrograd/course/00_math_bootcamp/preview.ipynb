# %% [markdown]
# # Preview - 预测斜率
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

# %%
# TODO: y = 2x + 1 在任何点附近的斜率是多少？
predict_slope = None

def qa_check_preview_00(value):
    if not todo_guard([value]): return
    assert value == 2, '斜率应该是 2。'
    print('OK: 你已经抓住一元导数=局部斜率。')

qa_check_preview_00(predict_slope)
