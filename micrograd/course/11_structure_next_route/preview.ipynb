# %% [markdown]
# # Preview - 文件职责
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

# %%
# TODO: engine.py 主要实现什么？填 'Value' 或 'MLP'
engine_role = None
# TODO: nn.py 主要实现什么？填 'Value' 或 'MLP'
nn_role = None

def qa_check_preview_11(engine, nn):
    if not todo_guard([engine, nn]): return
    assert engine == 'Value'
    assert nn == 'MLP'
    print('OK: 项目结构入口通过。')

qa_check_preview_11(engine_role, nn_role)
