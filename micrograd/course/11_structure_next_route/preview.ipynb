# %% [markdown]
# # Preview - 文件职责
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

from course.checks import qa_check

# %%
# 填写说明：
# - 完成 student_preview_structure_probe，直接检查 micrograd 两个模块里有什么。
# - 运行本 cell，看 qa_check 的提示。


def student_preview_structure_probe():
    import micrograd.engine as engine
    import micrograd.nn as nn
    # TODO: 返回 engine_has_value 和 nn_has_mlp。
    pass


qa_check('qa_check_preview_11', globals(), student_preview_structure_probe)

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - `engine.py` 里应该能找到 `Value`。
# - `nn.py` 里应该能找到 `MLP`。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
# ```python
# def student_preview_structure_probe():
#     import micrograd.engine as engine
#     import micrograd.nn as nn
#     return {
#         'engine_has_value': hasattr(engine, 'Value'),
#         'nn_has_mlp': hasattr(nn, 'MLP'),
#     }
# ```
#
# </details>
