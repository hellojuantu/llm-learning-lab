# %% [markdown]
# # Preview - 定位 zero_grad
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

# %%
# 同一张图/同一批参数反复 backward 时，grad 会累加。
# TODO: 每轮训练 backward 前应该调用什么？填字符串，例如 'xxx()'
student_call = None

def qa_check_preview_09(call):
    if not todo_guard([call]): return
    assert call == 'zero_grad()'
    print('OK: 训练循环调试第一件事就是看 zero_grad。')

qa_check_preview_09(student_call)
