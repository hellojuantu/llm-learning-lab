# %% [markdown]
# # Preview - 预测乘法梯度
#
# 先做一个很小的预测题，再进 class notebook。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

from course.checks import qa_check

# %%
# 填写说明：
# - 填两个数字：L=a*b 在 a=2,b=3 时，dL/da 和 dL/db。
# - 填完后运行本 cell，看 qa_check 的提示。

# L = a*b, a=2, b=3
# TODO: dL/da 和 dL/db 分别是多少？
predict_dL_da = None
predict_dL_db = None


qa_check('qa_check_preview_01', globals(), predict_dL_da, predict_dL_db)

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 先写局部导数：加法传 1，乘法乘另一个输入；如果同一个变量出现两次，要把两条贡献相加。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `da` 填 `3`。
# - `db` 填 `2`。
#
# </details>
