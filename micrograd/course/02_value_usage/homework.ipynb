# %% [markdown]
# # Homework 02 - Value Usage
#
# 目标：只从使用者视角观察 `data`、`grad`、`backward()`。

# %%
from pathlib import Path
import sys, math, random


def find_repo_root():
    p = Path.cwd().resolve()
    for q in [p, *p.parents]:
        if (q / 'micrograd' / 'engine.py').exists():
            return q
    return p

ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def near(a, b, eps=1e-6):
    return abs(a - b) < eps


def todo_guard(values, message='请先填写 TODO，再运行检查。'):
    if any(v is None for v in values):
        print(message)
        return False
    return True

import importlib
import course.checks as course_checks
importlib.reload(course_checks)
qa_check = course_checks.qa_check

# %% [markdown]
# ## 完整例子 - 先看 data，再看 grad
#
# 同一个表达式，`data` 来自前向计算，`grad` 来自 backward 后的反向传播。

# %%
from micrograd.engine import Value

ex_a = Value(2.0)
ex_b = Value(3.0)
ex_L = (ex_a * ex_b + ex_a) * 2
print('before backward:', ex_L, ex_a, ex_b)
ex_L.backward()
print('after backward:', ex_L, ex_a, ex_b)

# %% [markdown]
# ## Modify - 只改 `a` 的值
#
# 参考完整例子，把 `a=2` 改成 `a=4`，重新预测 `L.data`、`a.grad`、`b.grad`。

# %%
# 填写说明：
# - 填三个数字：改输入后预测 L.data、a.grad、b.grad。
# - 填完后运行本 cell，看 qa_check 的提示。

student_modify_L_data = None
student_modify_a_grad = None
student_modify_b_grad = None



qa_check('qa_check_02_modify', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 先分清 `data` 和 `grad`：`data` 前向就有，`grad` 要在 `backward()` 后才有；重复 backward 会累加。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `student_modify_L_data` 填 `L.data == 32.0`。
# - `student_modify_a_grad` 填 `a.grad == 8.0`。
# - `student_modify_b_grad` 填 `b.grad == 8.0`。
#
# </details>

# %%
# 填写说明：
# - student_data 填 [a,b,c,d,L] 的前向 data 列表；student_grads 填 backward 后各节点 grad 列表。
# - 填完后运行本 cell，看 qa_check 的提示。

from micrograd.engine import Value

a = Value(2.0)
b = Value(3.0)
c = a * b
d = c + a
L = d * 2

# 作业 1：先预测前向 data
student_data = None  # 形如 [a,b,c,d,L]

# 作业 2：运行 backward 后预测 grad
student_grads = None # 形如 [a.grad,b.grad,c.grad,d.grad,L.grad]



qa_check('qa_check_value_usage', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 先分清 `data` 和 `grad`：`data` 前向就有，`grad` 要在 `backward()` 后才有；重复 backward 会累加。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
#
# 参考答案（先自己做，卡住再展开）：
#
# - `student_data` 填 `[2.0, 3.0, 6.0, 8.0, 16.0]`。
# - `student_grads` 填 `actual`。
# - `student_grads` 填 `[8.0, 4.0, 2, 2, 1]`。
#
# </details>

# %%
# 填写说明：
# - 完成函数，亲手制造“重复 backward 会累加 grad”的现象。
# - 运行本 cell，看 qa_check 的提示。

from micrograd.engine import Value


def student_repeat_backward_demo():
    # TODO 1: 用同一张图算 L = 2(ab+a)，调用 backward 两次，记录 a.grad。
    a = Value(2.0)
    b = Value(3.0)
    L = (a * b + a) * 2
    # first_grad = ...
    # second_grad = ...

    # TODO 2: 重新建一张新图，只 backward 一次，记录 fresh_grad。
    # fresh_grad = ...
    pass


qa_check('qa_check_repeat_backward', globals())

# %% [markdown]
# <details><summary>Show / Hide 本题提示</summary>
#
# - 同一张图：`L.backward()` 第一次后 `a.grad` 是 8；第二次会继续加上新的贡献。
# - 重新建图不是“清空旧图”，而是创建全新的 `Value` 对象。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 本题答案</summary>
#
# ```python
# def student_repeat_backward_demo():
#     a = Value(2.0)
#     b = Value(3.0)
#     L = (a * b + a) * 2
#     L.backward()
#     first_grad = a.grad
#     L.backward()
#     second_grad = a.grad
#
#     fresh_a = Value(2.0)
#     fresh_b = Value(3.0)
#     fresh_L = (fresh_a * fresh_b + fresh_a) * 2
#     fresh_L.backward()
#     fresh_grad = fresh_a.grad
#     return first_grad, second_grad, fresh_grad
# ```
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 提示</summary>
#
# 先找完整例子的形状，再只改一个地方。填 TODO 前，先用小数字在纸上算一遍；测试失败时先判断错在数学、Python、计算图还是训练循环。
#
# </details>

# %% [markdown]
# <details><summary>Show / Hide 答案</summary>
#
# 答案不要一开始看。正确答案应该能由完整例子和 Modify 题一步推出；如果你需要直接看答案，说明前一个台阶还没踩稳。
#
# </details>

# %% [markdown]
# ## 提交清单
#
# - [ ] 我跑过完整例子。
# - [ ] 我完成了 Modify 题。
# - [ ] 我完成了 TODO 作业并通过 qa_check。
# - [ ] 我修过 Debug Lab。
# - [ ] 我能说出本节知识如何接回 micrograd 主线。
